# %%
# !pip3 install scrublet

# %%
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sc.settings.verbosity = 3
sc.logging.print_versions()

import gc
# Out:
# -----
# anndata     0.10.9
# scanpy      1.10.3
# -----
# PIL                 10.4.0
# asttokens           NA
# cffi                1.16.0
# comm                0.2.2
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.9.0
# debugpy             1.8.5
# decorator           5.1.1
# dill                0.3.8
# exceptiongroup      1.2.2
# executing           2.1.0
# h5py                3.11.0
# ipykernel           6.29.5
# jedi                0.19.1
# joblib              1.4.2
# kiwisolver          1.4.7
# legacy_api_wrap     NA
# llvmlite            0.43.0
# matplotlib          3.9.2
# mpl_toolkits        NA
# mpmath              1.3.0
# natsort             8.4.0
# numba               0.60.0
# numpy               1.26.4
# nvfuser             NA
# packaging           24.1
# pandas              2.2.2
# parso               0.8.4
# pickleshare         0.7.5
# platformdirs        3.10.0
# prompt_toolkit      3.0.47
# psutil              6.0.0
# ...

# %%
gc.collect()
# Out:
# 0

# %%
adata = sc.read_h5ad("/local/home/am/EX_M/datasets/scRNA/heart/heart.h5ad")
adata
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 adata = sc.read_h5ad("/local/home/am/EX_M/datasets/scRNA/heart/heart.h5ad")
#       2 adata
#
# File /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_io/h5ad.py:234, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     226         raise NotImplementedError(
#     227             "Currently only `X` and `raw/X` can be read as sparse."
#     228         )
#     230 rdasp = partial(
#     231     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     232 )
# --> 234 with h5py.File(filename, "r") as f:
#     236     def callback(func, elem_name: str, elem, iospec):
#     237         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# ...

# %%
adata.var_names_make_unique()
sc.pp.filter_genes(adata, min_cells=3)
adata.layers["counts"] = adata.X.copy()
# sc.pp.filter_cells(adata, min_genes=10) # already done in the original dataset
adata
# Out:
# filtered out 61 genes that are detected in less than 3 cells
# AnnData object with n_obs × n_vars = 60668 × 27350
#     obs: 'nCount_RNA', 'nFeature_RNA', 'age_group', 'cell_source', 'cell_states', 'sample', 'age.order', 'age.days.GA', 'size.CRL', 'size.NRL', 'stage', 'integration.groups', 'integrated_snn_res.0.1', 'clusters.low.res', 'clusters.high.res', 'clusters.res.2', 'clusters.res.3', 'condition', 'tissue_ontology_term_id', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'donor_id', 'suspension_type', 'is_primary_data', 'tissue_type', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells'
# ...

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
adata.write('/local/home/am/EX_M/datasets/scRNA/heart/heart_preprocessed.h5ad')
