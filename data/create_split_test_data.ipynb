# %%
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
import scipy.io
from matplotlib import rcParams
from matplotlib import colors
import seaborn as sb
import gc

# sc.settings.verbosity = 3
# sc.logging.print_versions()
seed = 32
np.random.seed(seed)

# %%
def sample_from_adata(adata, n_splits=5, n=None):
    """
    Sample n cells from an AnnData object.
    """
    if n is not None and n > adata.n_obs:
        raise ValueError("n cannot be greater than the number of observations in adata.")
    
    all_cell_types = set(adata.obs['celltype'])
    if n is None:
        n = (4 * adata.n_obs) // 5
    obs_names = adata.obs_names.values

    sampled_adatas = []

    for _ in range(n_splits):
        while True:
            chosen = np.random.choice(obs_names, size=n, replace=True)
            if set(adata.obs.loc[chosen, 'celltype']) == all_cell_types:
                sampled_adatas.append(adata[chosen].copy())
                break

    return sampled_adatas

# %% [markdown]
# ### scFoundation

# %% [markdown]
# ##### Bone Marrow

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/merged/seed_32/scFoundation/test/bone_marrow_test_processed.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 36249 × 19264
#     obs: 'dataset', 'sample', 'donor_status', 'donor', 'timepoint', 'celltype', 'n_genes', 'set', 'ID', 'label'
#     uns: 'celltype_colors', 'dataset_colors', 'hvg', 'neighbors', 'timepoint_colors', 'umap'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/merged/seed_32/scFoundation/test/bone_marrow_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### pbmc68K

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/pbmc68k/seed_32/scFoundation/test/pbmc68k_test_processed.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 6856 × 19264
#     obs: 'celltype', 'n_genes', 'set', 'ID', 'label'
#     uns: 'hvg', 'log1p'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/pbmc68k/seed_32/scFoundation/test/pbmc68k_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### Heart

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/heart/seed_32/scFoundation/test/heart_test_processed.h5ad')
adata
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 6067 × 19265
# ...

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/heart/seed_32/scFoundation/test/heart_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### Retina

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/retina/seed_32/scFoundation/test/retina_test_processed.h5ad')
adata
# Out:
# /local/home/am/miniconda3/envs/base_clone/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 5161 × 19266
#     obs: 'biosample_id', 'donor_id', 'cell_type_ontology_term_id', 'disease_ontology_term_id', 'tissue_ontology_term_id', 'assay_ontology_term_id', 'cell_type__custom', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'suspension_type', 'is_primary_data', 'age', 'self_reported_ethnicity_ontology_term_id', 'tissue_type', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_genes', 'celltype', 'set', 'ID', 'label'
#     uns: 'citation', 'hvg', 'log1p', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/envs/base_clone/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/envs/base_clone/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /local/home/am/miniconda3/envs/base_clone/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/envs/base_clone/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/retina/seed_32/scFoundation/test/retina_test_sampled_{i}.h5ad')

# %% [markdown]
# ### scGPT

# %% [markdown]
# ##### Bone Marrow

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/merged/seed_32/scGPT/test/bone_marrow_test.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 36249 × 16723
#     obs: 'dataset', 'sample', 'donor_status', 'donor', 'timepoint', 'celltype', 'n_genes', 'set', 'ID'
#     var: 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'celltype_colors', 'dataset_colors', 'hvg', 'neighbors', 'timepoint_colors', 'umap'
#     obsm: 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs['ID']
# Out:
# AAACCCAAGCGGATCA-1-1216_Dg        0
# AAACGAAAGGGTAATT-1-1216_Dg        1
# AAACGAACATACCACA-1-1216_Dg        2
# AAACGAAGTATCAGGG-1-1216_Dg        3
# AAACGAAGTCGAACGA-1-1216_Dg        4
#                               ...
# ATACTACTTCCN-1-BM1            36244
# AGGAGCGGTTGG-1-BM1            36245
# CGCGAGAAGGGA-1-BM1            36246
# TATGTAGTTCGG-1-BM1            36247
# AGTGGCAGGAGC-1-BM1            36248
# Name: ID, Length: 36249, dtype: int64

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/merged/seed_32/scGPT/test/bone_marrow_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### pbmc68K

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/pbmc68k/seed_32/scGPT/test/pbmc68k_test.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 6856 × 17788
#     obs: 'celltype', 'n_genes', 'set', 'ID'
#     var: 'gene_ids', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'hvg', 'log1p'
#     layers: 'counts'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/pbmc68k/seed_32/scGPT/test/pbmc68k_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### Heart

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/heart/seed_32/scGPT/test/heart_test.h5ad')
adata
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 6067 × 27350
# ...

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/heart/seed_32/scGPT/test/heart_test_sampled_{i}.h5ad')

# %% [markdown]
# ### Geneformer

# %% [markdown]
# ##### Bone Marrow

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/merged/seed_32/geneformer/bone_marrow_test.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 36249 × 16723
#     obs: 'dataset', 'sample', 'donor_status', 'donor', 'timepoint', 'celltype', 'n_genes', 'set', 'ID'
#     var: 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'celltype_colors', 'dataset_colors', 'hvg', 'neighbors', 'timepoint_colors', 'umap'
#     obsm: 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/merged/seed_32/geneformer/bone_marrow_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### pbmc68K

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/pbmc68k/seed_32/geneformer/pbmc68k_test.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 6856 × 17788
#     obs: 'celltype', 'n_genes', 'set', 'ID'
#     var: 'gene_ids', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'hvg', 'log1p'
#     layers: 'counts'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/pbmc68k/seed_32/geneformer/pbmc68k_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### heart

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/heart/seed_32/geneformer/heart_test.h5ad')
adata
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 6067 × 27350
# ...

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/heart/seed_32/geneformer/heart_test_sampled_{i}.h5ad')

# %% [markdown]
# ### scBERT

# %% [markdown]
# ##### Bone Marrow

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/merged/seed_32/scBERT/bone_marrow_test.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 36249 × 16723
#     obs: 'dataset', 'sample', 'donor_status', 'donor', 'timepoint', 'celltype', 'n_genes', 'set', 'ID'
#     var: 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'celltype_colors', 'dataset_colors', 'hvg', 'neighbors', 'timepoint_colors', 'umap'
#     obsm: 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/merged/seed_32/scBERT/bone_marrow_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### pbmc68k

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/pbmc68k/seed_32/scBERT/pbmc68k_test_preprocessed.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 6844 × 16906
#     obs: 'celltype', 'n_genes', 'set', 'ID'
#     uns: 'log1p'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/pbmc68k/seed_32/scBERT/pbmc68k_test_sampled_{i}.h5ad')

# %% [markdown]
# ##### heart

# %%
adata = sc.read('/local/home/am/EX_M/datasets/scRNA/heart/seed_32/scBERT/heart_test_preprocessed.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 6067 × 16906
#     obs: 'nCount_RNA', 'nFeature_RNA', 'age_group', 'cell_source', 'cell_states', 'sample', 'age.order', 'age.days.GA', 'size.CRL', 'size.NRL', 'stage', 'integration.groups', 'integrated_snn_res.0.1', 'clusters.low.res', 'clusters.high.res', 'clusters.res.2', 'clusters.res.3', 'condition', 'tissue_ontology_term_id', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'donor_id', 'suspension_type', 'is_primary_data', 'tissue_type', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_genes', 'celltype', 'set', 'ID'
#     uns: 'log1p'

# %%
samples = sample_from_adata(adata)
# Out:
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /local/home/am/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ...

# %%
for i, sample in enumerate(samples):
    sample.write(f'/local/home/am/EX_M/datasets/scRNA/heart/seed_32/scBERT/heart_test_sampled_{i}.h5ad')
